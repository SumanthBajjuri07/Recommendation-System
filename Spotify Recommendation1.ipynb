# %%
import pandas as pd

df = pd.read_csv(r"Documents\spotify_data.csv")

# %%
df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.803  0.6240    7    -6.764     0       0.0477        0.4510
# 1           0.762  0.7030   10    -7.951     0       0.3060        0.2060
# 2           0.261  0.0149    1   -27.528     1       0.0419        0.9920
# 3           0.722  0.7360    3    -6.994     0       0.0585        0.4310
# 4           0.787  0.5720    1    -7.516     1       0.2220        0.1450
# ..            ...     ...  ...       ...   ...          ...           ...
# 190         0.166  0.0551    9   -19.494     0       0.0520        0.9760
# 191         0.862  0.6240    3   -11.630     1       0.0565        0.0192
# 192         0.499  0.3510    9   -11.509     0       0.0448        0.9510
# 193         0.574  0.7290   10    -5.838     0       0.0965        0.0406
# 194         0.747  0.6660   11    -7.845     1       0.1970        0.1300
#
#      instrumentalness  liveness  valence    tempo  duration_ms  \
# 0            0.000734    0.1000   0.6280   95.968       304524
# 1            0.000000    0.0912   0.5190  151.329       247178
# 2            0.897000    0.1020   0.0382   75.296       286987
# 3            0.000001    0.1230   0.5820   89.860       208920
# 4            0.000000    0.0753   0.6470  155.117       179413
# ..                ...       ...      ...      ...          ...
# 190          0.635000    0.1190   0.1430  176.616       206520
# 191          0.000153    0.0465   0.8820  124.896       254240
# 192          0.000099    0.1180   0.6160   90.664       235947
# 193          0.000004    0.1940   0.4130  110.547       190239
# 194          0.000000    0.3600   0.5310   77.507       177213
#
#      time_signature  liked
# 0                 4      0
# 1                 4      1
# 2                 4      0
# 3                 4      1
# 4                 4      1
# ..              ...    ...
# 190               3      0
# 191               4      0
# 192               4      0
# 193               5      1
# 194               4      1
#
# [195 rows x 14 columns]

# %%
import numpy as np
import json

# %%
df= df.sample(frac=1)
df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 124         0.915  0.5510    8   -10.490     1       0.3430      0.034200
# 18          0.754  0.4750    1   -10.889     1       0.1540      0.523000
# 112         0.705  0.9700    8    -3.280     1       0.2590      0.241000
# 128         0.609  0.5170    6    -7.557     0       0.0451      0.231000
# 148         0.726  0.7150    5    -4.261     0       0.0662      0.001080
# ..            ...     ...  ...       ...   ...          ...           ...
# 190         0.166  0.0551    9   -19.494     0       0.0520      0.976000
# 147         0.483  0.9410    2    -3.598     0       0.0575      0.000526
# 81          0.620  0.5730    0   -11.893     1       0.0423      0.271000
# 93          0.798  0.7460   10    -8.639     1       0.0313      0.030400
# 129         0.213  0.0656    7   -24.810     1       0.0467      0.992000
#
#      instrumentalness  liveness  valence    tempo  duration_ms  \
# 124          0.000000    0.1020   0.7530  124.906        88320
# 18           0.000000    0.1130   0.2350  117.006       201384
# 112          0.000000    0.2890   0.7660   99.970       194138
# 128          0.000036    0.0777   0.0761  120.914       285627
# 148          0.000046    0.1820   0.7670  140.061       183428
# ..                ...       ...      ...      ...          ...
# 190          0.635000    0.1190   0.1430  176.616       206520
# 147          0.000004    0.3100   0.5030  156.033       232067
# 81           0.000000    0.0607   0.8970   81.548       231333
# 93           0.361000    0.0703   0.9650  128.553       655213
# 129          0.969000    0.0699   0.0384   65.023       150147
#
#      time_signature  liked
# 124               4      1
# 18                4      1
# 112               4      1
# 128               4      0
# 148               4      1
# ..              ...    ...
# 190               3      0
# 147               4      1
# 81                4      0
# 93                4      0
# 129               3      0
#
# [195 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'time_signature', 'liked'],
#       dtype='object')

# %%
df.shape
# Out:
# (195, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195 entries, 124 to 129
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      195 non-null    float64
#  1   energy            195 non-null    float64
#  2   key               195 non-null    int64
#  3   loudness          195 non-null    float64
#  4   mode              195 non-null    int64
#  5   speechiness       195 non-null    float64
#  6   acousticness      195 non-null    float64
#  7   instrumentalness  195 non-null    float64
#  8   liveness          195 non-null    float64
#  9   valence           195 non-null    float64
#  10  tempo             195 non-null    float64
#  11  duration_ms       195 non-null    int64
#  12  time_signature    195 non-null    int64
#  13  liked             195 non-null    int64
# dtypes: float64(9), int64(5)
# memory usage: 22.9 KB

# %%
df['liked'].value_counts()
# Out:
# 1    100
# 0     95
# Name: liked, dtype: int64

# %%
df.isna().sum()
# Out:
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# liked               0
# dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df1=df

# %%
df.head()
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 124         0.915   0.551    8   -10.490     1       0.3430       0.03420
# 18          0.754   0.475    1   -10.889     1       0.1540       0.52300
# 112         0.705   0.970    8    -3.280     1       0.2590       0.24100
# 128         0.609   0.517    6    -7.557     0       0.0451       0.23100
# 148         0.726   0.715    5    -4.261     0       0.0662       0.00108
#
#      instrumentalness  liveness  valence    tempo  duration_ms  \
# 124          0.000000    0.1020   0.7530  124.906        88320
# 18           0.000000    0.1130   0.2350  117.006       201384
# 112          0.000000    0.2890   0.7660   99.970       194138
# 128          0.000036    0.0777   0.0761  120.914       285627
# 148          0.000046    0.1820   0.7670  140.061       183428
#
#      time_signature  liked
# 124               4      1
# 18                4      1
# 112               4      1
# 128               4      0
# 148               4      1

# %%
df['liked'].value_counts().plot(kind='pie',autopct='%.2f',)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.pairplot(data=df, hue='liked')
plt.show()

# %%
sns.countplot(df['liked']);
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(16, 9))
sns.heatmap(df.corr(), annot=True, cmap='YlGnBu')
plt.tight_layout()
plt.show()

# %%
sns.distplot(df['danceability']);
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['energy']);
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['key']);
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['loudness']);
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['mode']);
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['speechiness']);
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['acousticness']);
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['instrumentalness']);
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['liveness']);
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['valence']);
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['tempo']);
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['duration_ms']);
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['time_signature']);
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
corr = df.corr()[["liked"]]
fig, ax = plt.subplots(figsize=(10,10)) 
sns.heatmap(
    corr, 
    annot=True,
    ax=ax
);

# %%
df.corr().style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row0_col0,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row1_col1,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row2_col2,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row3_col3,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row4_col4,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row5_col5,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row6_col6,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row7_col7,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row8_col8,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row9_col9,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row10_col10,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row11_col11,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row12_col12,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row13_col13{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row0_col1,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row11_col6{
#             background-color:  #66abd4;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row0_col2,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row1_col4{
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row0_col3{
#             background-color:  #3585bf;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row0_col4,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row12_col2{
#             background-color:  #dce9f6;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row0_col5{
#             background-color:  #57a0ce;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row0_col6,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row4_col5,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row12_col11{
#             background-color:  #b5d4e9;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row0_col7,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row1_col6,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row4_col2,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row6_col1,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row6_col3,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row6_col8,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row7_col0,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row7_col9,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row7_col10,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row7_col12,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row7_col13,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row11_col5,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row11_col8,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row12_col4,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row13_col11{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row0_col8,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row2_col4,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row12_col8{
#             background-color:  #f6faff;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row0_col9{
#             background-color:  #2070b4;
#             color:  #f1f1f1;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row0_col10{
#             background-color:  #92c4de;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row0_col11,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row7_col8,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row8_col12{
#             background-color:  #d5e5f4;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row0_col12,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row10_col9{
#             background-color:  #6aaed6;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row0_col13{
#             background-color:  #2777b8;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row1_col0{
#             background-color:  #64a9d3;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row1_col2,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row2_col5{
#             background-color:  #cde0f1;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row1_col3{
#             background-color:  #084d96;
#             color:  #f1f1f1;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row1_col5,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row8_col0{
#             background-color:  #a0cbe2;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row1_col7{
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row1_col8{
#             background-color:  #bfd8ed;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row1_col9,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row5_col3,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row10_col0{
#             background-color:  #549fcd;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row1_col10,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row2_col6,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row4_col1,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row9_col10{
#             background-color:  #95c5df;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row1_col11,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row12_col7{
#             background-color:  #c8dcf0;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row1_col12,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row11_col1{
#             background-color:  #a3cce3;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row1_col13{
#             background-color:  #75b4d8;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row2_col0{
#             background-color:  #8fc2de;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row2_col1{
#             background-color:  #68acd5;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row2_col3{
#             background-color:  #89bedc;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row2_col7,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row8_col3{
#             background-color:  #81badb;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row2_col8{
#             background-color:  #e5eff9;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row2_col9,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row4_col9{
#             background-color:  #9ac8e0;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row2_col10,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row2_col12{
#             background-color:  #b4d3e9;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row2_col11{
#             background-color:  #a1cbe2;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row2_col13,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row13_col6{
#             background-color:  #abd0e6;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row3_col0{
#             background-color:  #2f7fbc;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row3_col1{
#             background-color:  #084b93;
#             color:  #f1f1f1;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row3_col2{
#             background-color:  #dceaf6;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row3_col4,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row3_col6{
#             background-color:  #ebf3fb;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row3_col5{
#             background-color:  #72b2d8;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row3_col7{
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row3_col8,#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row4_col12{
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }#T_fd677310_7c37_11ec_82a2_d0bf9c9140b7row3_col9{
#             background-color:  #4b98ca;
#             color:  #000000;
#         }#T_fd6773

# %% [raw]
# Correlation between all features and target column - 'Liked'
# Just based off this correlation matrix, we can tell that this spotify user has a preference for songs:
#
#
# 1.scoring high on - danceability, loudness, speechiness
# 2.scoring low on - instrumentalness, duration

# %%
liked = df['liked'] == 1
disliked = df['liked'] == 0
liked_songs = df[liked]
disliked_songs = df[disliked]

plt.figure(figsize=(8,6))
plt.hist(liked_songs['speechiness'], alpha=0.5, label="liked songs")
plt.hist(disliked_songs['speechiness'], alpha=0.5, label="disliked songs")

plt.xlabel("Speechiness", size=14)
plt.ylabel("Count", size=14)
plt.title("Comparison of speechiness between liked and disliked songs")
plt.legend(loc='upper right')

# %% [markdown]
# Here, we can see that almost all of the user's disliked songs score very low on Speechiness.

# %%
plt.figure(figsize=(8,6))
plt.hist(liked_songs['danceability'], alpha=0.5, label="liked songs")
plt.hist(disliked_songs['danceability'], alpha=0.5, label="disliked songs")

plt.xlabel("Speechiness", size=14)
plt.ylabel("Count", size=14)
plt.title("Comparison of danceability between liked and disliked songs")
plt.legend(loc='upper right')

# %% [markdown]
# And here, we can see that many of the user's liked songs score very high on Danceability.
#
# From the two charts above, we can see that even if a song scores high on Danceability, it still wouldn't guarantee the user's like. We can also see that even if a song scores low on speechiness, it doesn't guarantee the user's dislike.
#
# And if we combine these two features, we might get a starker difference

# %%
high_speechiness = df['speechiness'] > 0.3 
high_danceability = df['danceability'] > 0.6

songs_with_high_dance_and_speech = df[high_speechiness & high_danceability]
plt.title("Distribution of likes among songs with high speechiness and danceability")
songs_with_high_dance_and_speech['liked'].value_counts().sort_values().plot(kind = 'barh')
# Out:
# <AxesSubplot:title={'center':'Distribution of likes among songs with high speechiness and danceability'}>

# %%
songs_with_low_dance_and_speech = df[~high_speechiness & ~high_danceability]
plt.title("Distribution of likes among songs with low speechiness and danceability")
songs_with_low_dance_and_speech['liked'].value_counts().plot(kind = 'barh')
# Out:
# <AxesSubplot:title={'center':'Distribution of likes among songs with low speechiness and danceability'}>

# %% [markdown]
# It looks like if a song scores highly on both speechiness and danceability, it's very likely to get the user's like. And the opposite is true: if a song scores low on both speechiness and danceability, it would also be more likely to be disliked.
#
# Another interesting thing I noted in the correlation matrix was how danceability have a very strong inverse relationship to instrumentalness (which makes sense). lets see how this relationship would look

# %%
plt.plot(df['danceability'], df['instrumentalness'], 'o', markersize = 4, alpha=0.6)
plt.title("Scatter plot of songs based on instrumentalness and danceability")
plt.xlabel("Danceability", size=14)
plt.ylabel("Instrumentalness", size=14)
# Out:
# Text(0, 0.5, 'Instrumentalness')

# %%
from scipy.stats import linregress

xs = df['danceability']
ys = df['instrumentalness']

# Compute the linear regression
res = linregress(xs, ys)

# Plot the line of best fit
fx = np.array([xs.min(), xs.max()])
fy = res.slope * fx + res.intercept
plt.plot(fx, fy, '-', alpha=0.7)

plt.title("Best fit line of relationship between instrumentalness and danceability")
plt.xlabel("Danceability", size=14)
plt.ylabel("Instrumentalness", size=14)
# Out:
# Text(0, 0.5, 'Instrumentalness')

# %%
c = df.corr()
c['liked'].sort_values(kind="quicksort")
# Out:
# instrumentalness   -0.569440
# duration_ms        -0.490651
# acousticness       -0.179375
# key                -0.044406
# liveness           -0.009797
# mode                0.023747
# energy              0.176179
# time_signature      0.221479
# valence             0.268653
# tempo               0.371202
# loudness            0.410774
# danceability        0.569425
# speechiness         0.591505
# liked               1.000000
# Name: liked, dtype: float64

# %%
x = df.drop('liked', axis = 1).values 
y = df[['liked']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(solver='liblinear')

# %%
x_train
# Out:
# array([[6.51000e-01, 6.39000e-01, 3.00000e+00, ..., 1.57738e+02,
#         2.47440e+05, 4.00000e+00],
#        [6.08000e-01, 4.71000e-01, 0.00000e+00, ..., 7.07020e+01,
#         1.65800e+05, 3.00000e+00],
#        [7.98000e-01, 5.64000e-01, 2.00000e+00, ..., 1.08004e+02,
#         2.54218e+05, 4.00000e+00],
#        ...,
#        [2.50000e-01, 9.82000e-01, 1.00000e+00, ..., 1.36707e+02,
#         1.26333e+05, 4.00000e+00],
#        [7.87000e-01, 5.72000e-01, 1.00000e+00, ..., 1.55117e+02,
#         1.79413e+05, 4.00000e+00],
#        [5.92000e-01, 3.71000e-01, 9.00000e+00, ..., 1.27966e+02,
#         3.16546e+05, 4.00000e+00]])

# %%
x_test
# Out:
# array([[ 8.62000e-01,  6.24000e-01,  3.00000e+00, -1.16300e+01,
#          1.00000e+00,  5.65000e-02,  1.92000e-02,  1.53000e-04,
#          4.65000e-02,  8.82000e-01,  1.24896e+02,  2.54240e+05,
#          4.00000e+00],
#        [ 4.63000e-01,  1.55000e-01,  5.00000e+00, -1.71640e+01,
#          1.00000e+00,  4.40000e-02,  8.77000e-01,  2.61000e-01,
#          1.05000e-01,  2.22000e-01,  1.22437e+02,  3.01720e+05,
#          4.00000e+00],
#        [ 9.01000e-01,  9.39000e-01,  6.00000e+00, -2.76200e+00,
#          1.00000e+00,  2.74000e-01,  1.17000e-01,  0.00000e+00,
#          1.28000e-01,  3.66000e-01,  1.19303e+02,  2.09440e+05,
#          5.00000e+00],
#        [ 7.22000e-01,  7.36000e-01,  3.00000e+00, -6.99400e+00,
#          0.00000e+00,  5.85000e-02,  4.31000e-01,  1.18000e-06,
#          1.23000e-01,  5.82000e-01,  8.98600e+01,  2.08920e+05,
#          4.00000e+00],
#        [ 5.39000e-01,  4.87000e-01,  1.00000e+00, -9.65300e+00,
#          1.00000e+00,  2.02000e-01,  3.09000e-01,  0.00000e+00,
#          9.70000e-02,  3.75000e-01,  1.69985e+02,  1.86353e+05,
#          4.00000e+00]])

# %%
 y_train
# Out:
#      liked
# 145      0
# 34       0
# 92       0
# 88       0
# 170      0
# ..     ...
# 153      0
# 188      1
# 126      0
# 4        1
# 117      0
#
# [156 rows x 1 columns]

# %%
y_test
# Out:
#      liked
# 191      0
# 168      0
# 99       1
# 192      0
# 157      0
# 38       0
# 45       0
# 114      0
# 152      1
# 110      0
# 116      0
# 111      1
# 166      1
# 101      1
# 33       1
# 98       1
# 16       1
# 150      1
# 81       0
# 144      0
# 159      0
# 181      1
# 59       0
# 180      0
# 47       1
# 69       1
# 165      1
# 15       0
# 21       0
# 28       1
# 75       0
# 7        1
# 95       0
# 176      0
# 83       0
# 40       0
# 120      1
# 3        1
# 74       0

# %%
lr.fit(x_train, y_train)
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# LogisticRegression(solver='liblinear')

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import classification_report

def confusion_matrix(actuals,predicted):
    cm = metrics.confusion_matrix(actuals,predicted,[1,0])
    sns.heatmap(cm, annot = True, fmt ='.2f', xticklabels=['Liked', 'Not Liked'], 
                yticklabels=['Liked', 'Not Liked'])
    
    plt.ylabel("Actual Labels")
    plt.xlabel("Predicted Labels")

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.73      0.76        22
#            1       0.68      0.76      0.72        17
#
#     accuracy                           0.74        39
#    macro avg       0.74      0.75      0.74        39
# weighted avg       0.75      0.74      0.74        39

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
import sklearn.metrics as metrics
confusion_matrix(y_test, y_pred)

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Create first pipeline for base without reducing features.
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
pipe = Pipeline([('classifier' , RandomForestClassifier())])
# pipe = Pipeline([('classifier', RandomForestClassifier())])

# Create param grid.

param_grid = [
    {'classifier' : [LogisticRegression()],
     'classifier__penalty' : ['l1', 'l2'],
    'classifier__C' : np.logspace(-4, 4, 20),
    'classifier__solver' : ['liblinear']},
    {'classifier' : [RandomForestClassifier()],
    'classifier__n_estimators' : list(range(10,101,10)),
    'classifier__max_features' : list(range(6,32,5))}
]

# Create grid search object

clf = GridSearchCV(pipe, param_grid = param_grid, cv = 5, verbose=True, n_jobs=-1)

# Fit on data

best_clf = clf.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   20.6s finished

# %%
y_pred2 = clf.predict(x_test)

# %%
print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95        22
#            1       0.89      1.00      0.94        17
#
#     accuracy                           0.95        39
#    macro avg       0.95      0.95      0.95        39
# weighted avg       0.95      0.95      0.95        39

# %%
confusion_matrix(y_test, y_pred2)
